# %% [markdown]
# # TR Wiktionary Etymology Parse
#
# We parse the TR Wiktionary corpus and extract the etymology related fields. Note the following key issues:
#
# - Many words are missing etymologies
# - There are obvious errors in the source
# - We only extract etymology from Turkish words (i.e. if the exact same word exists in another language, we discard the etymology related to that

# %%
import xmltodict

import xml, sqlite3 as sql
from xml.dom import minidom
from xml.etree import ElementTree as ET

import re
import pprint
import pandas as pd

import pickle

# %%
parsed_xml = ET.parse("../../trwiktionary-20160305-pages-articles-multistream.xml")

# %%
root = parsed_xml.getroot()

# %%
p = root.findall("page") # grab the pages

# %%
texts = {}
for page in p:
    txt = page.find("revision/text").text
    title = page.find("title").text
    if txt is None:
        texts[title] = {}
    else:
        texts[title] = {"text": txt}

# %% [markdown]
# Cycle through all of the text in the dictionary and extract the language field:

# %%
for k, v in texts.items():
    txtfield = v.get("text")
    if txtfield is not None:
        # grab the language of the word
        langs = re.findall(r"\{\{Dil\|(\w+)\}\}", txtfield, flags=re.U)
        texts[k]["lang"] = langs
        
        # flag it if it is Turkish
        texts[k]["is_tr"] = u"Türkçe" in langs
        
        # extract etymology field
        match = re.findall(r"\{\{K\wken\}\}\n:(.*)", txtfield, flags=re.U)
        if len(match) > 0:
            texts[k]["etyms"] = re.findall(r"\{\{k\w*\|([\w|\s]*)\}\}", match[0], flags=re.U)

# %%
df = pd.DataFrame.from_dict(texts, "index")

# %%
dftr = df[df["is_tr"]]

# %%
dftr
# Out:
#                                lang  \
# -a                [Türkçe, Macarca]
# -acak                      [Türkçe]
# -ak                        [Türkçe]
# -aki                       [Türkçe]
# -alım                      [Türkçe]
# -amaç                      [Türkçe]
# -anç                       [Türkçe]
# -ar             [Türkçe, İngilizce]
# -ağan                      [Türkçe]
# -ca                        [Türkçe]
# -ce                        [Türkçe]
# -cı                        [Türkçe]
# -da                        [Türkçe]
# -dan                       [Türkçe]
# -daş                       [Türkçe]
# -de                        [Türkçe]
# -de hâli                   [Türkçe]
# -den                       [Türkçe]
# -den hâli                  [Türkçe]
# -deş                       [Türkçe]
# -dik              [Türkçe, Macarca]
# -dirik                     [Türkçe]
# -dı                        [Türkçe]
# -dırık                     [Türkçe]
# -e                [Türkçe, Macarca]
# -e hâli                    [Türkçe]
# -elim                      [Türkçe]
# -enç                       [Türkçe]
# -fobi                      [Türkçe]
# -gaç                       [Türkçe]
# ...                             ...
# şıpşıp                     [Türkçe]
# şıra            [Türkçe, Gagavuzca]
# şıra ölçer                 [Türkçe]
# şıracı                     [Türkçe]
# şıracılık                  [Türkçe]
# şırak                      [Türkçe]
# şırak şırak                [Türkçe]
# şırakkadak                 [Türkçe]
# şıralı                     [Türkçe]
# şıralık                    [Türkçe]
# şıralık üzüm               [Türkçe]
# şıraölçer                  [Türkçe]
# şırfıntı                   [Türkçe]
# şırlama                    [Türkçe]
# şırlamak                   [Türkçe]
# şırlanyağı                 [Türkçe]
# şırlağan        [Çağatayca, Türkçe]
# şırpıntı                   [Türkçe]
# şırıl şırıl                [Türkçe]
# şırıldama                  [Türkçe]
# şırıldamak                 [Türkçe]
# şırıltı                    [Türkçe]
# şırınga                    [Türkçe]
# şırınga etmek              [Türkçe]
# şırınga yapmak             [Türkçe]
# şırıngalama                [Türkçe]
# şırıngalamak               [Türkçe]
# şıvgın                     [Türkçe]
# π                   [Türkçe, Fince]
# مصايف                      [Türkçe]
#
#                                                              text is_tr  \
# -a              =={{Dil|Türkçe}}==\n==={{Söztürü|Ek|Türkçe}}==...  True
# -acak           {{Bakınız|açak|âcâk}}\n\n=={{Dil|Türkçe}}==\n=...  True
# -ak             {{Bakınız|ak|Ak|âk|AK}}\n\n=={{Dil|Türkçe}}==\...  True
# -aki            {{bakınız|aki}}\n=={{Dil|Türkçe}}==\n==={{Sözt...  True
# -alım           =={{Dil|Türkçe}}==\n==={{Söztürü|Ek|Türkçe}}==...  True
# -amaç           =={{Dil|Türkçe}}==\n==={{Söztürü|Ek|Türkçe}}==...  True
# -anç            =={{Dil|Türkçe}}==\n==={{Söztürü|Ek|Türkçe}}==...  True
# -ar             =={{Dil|Türkçe}}==\n==={{Söztürü|Ek|Türkçe}}==...  True
# -ağan           =={{Dil|Türkçe}}==\n==={{Söztürü|Ek|Türkçe}}==...  True
# -ca             =={{Dil|Türkçe}}==\n==={{Söztürü|Ek|Türkçe}}==...  True
# -ce             =={{Dil|Türkçe}}==\n==={{Söztürü|Ek|Türkçe}}==...  True
# -cı             =={{Dil|Türkçe}}==\n==={{Söztürü|Ek|Türkçe}}==...  True
# -da             =={{Dil|Türkçe}}==\n==={{Söztürü|Ek|Türkçe}}==...  True
# -dan            =={{Dil|Türkçe}}==\n==={{Söztürü|Ek|Türkçe}}==...  True
# -daş            =={{Dil|Türkçe}}==\n==={{Söztürü|Ek|Türkçe}}==...  True
# -de             =={{Dil|Türkçe}}==\n\n==={{Söz türü|Ek|Türkçe}...  True
# -de hâli        {{Ad Çekim Tablosu\n|Yalın (Tekil) = -de hâli\...  True
# -den            =={{Dil|Türkçe}}==\n\n==={{Söz türü|Ek|Türkçe}...  True
# -den hâli       =={{Dil|Türkçe}}==\n==={{Söz türü|Ad|Türkçe}}=...  True
# -deş            =={{Dil|Türkçe}}==\n==={{Söztürü|Ek|Türkçe}}==...  True
# -dik            =={{Dil|Türkçe}}==\n==={{Söztürü|Ek|Türkçe}}==...  True
# -dirik          =={{Dil|Türkçe}}==\n==={{Söztürü|Ek|Türkçe}}==...  True
# -dı             =={{Dil|Türkçe}}==\n==={{Söztürü|Ek|Türkçe}}==...  True
# -dırık          =={{Dil|Türkçe}}==\n==={{Söztürü|Ek|Türkçe}}==...  True
# -e              =={{Dil|Türkçe}}==\n==={{Söz türü|Ek|Türkçe}}=...  True
# -e hâli         =={{Dil|Türkçe}}==\n==={{Söz türü|Ad|Türkçe}}=...  True
# -elim           =={{Dil|Türkçe}}==\n==={{Söztürü|Ek|Türkçe}}==...  True
# -enç            =={{Dil|Türkçe}}==\n==={{Söztürü|Ek|Türkçe}}==...  True
# -fobi           {{Bakınız|fobi}}\n=={{Dil|Türkçe}}==\n==={{Söz...  True
# -gaç            =={{Dil|Türkçe}}==\n==={{Söztürü|Ek|Türkçe}}==...  True
# ...                                                           ...   ...
# şıpşıp          {{düzenle}}\n=={{Dil|Türkçe}}==\n==={{Söz türü...  True
# şıra            =={{Dil|Türkçe}}==\n==={{Söz türü|Ad|Türkçe}}=...  True
# şıra ölçer      {{düzenle}}\n=={{Dil|Türkçe}}==\n==={{Söz türü...  True
# şıracı          =={{Dil|Türkçe}}==\n==={{Söz türü|Ad|Türkçe}}=...  True
# şıracılık       =={{Dil|Türkçe}}==\n==={{Söz türü|Ad|Türkçe}}=...  True
# şırak           =={{Dil|Türkçe}}==\n==={{Söz türü|Ad|Türkçe}}=...  True
# şırak şırak     =={{Dil|Türkçe}}==\n==={{Söztürü|Zarf|Türkçe}}...  True
# şırakkadak      =={{Dil|Türkçe}}==\n==={{Söztürü|Zarf|Türkçe}}...  True
# şıralı          =={{Dil|Türkçe}}==\n==={{Söztürü|Ön ad|Türkçe}...  True
# şıralık         =={{Dil|Türkçe}}==\n==={{Söz türü|Ad|Türkçe}}=...  True
# şıralık üzüm    =={{Dil|Türkçe}}==\n==={{Söztürü|Ad|Türkçe}}==...  True
# şıraölçer       =={{Dil|Türkçe}}==\n==={{Söz türü|Ad|Türkçe}}=...  True
# şırfıntı        =={{Dil|Türkçe}}==\n==={{Söz türü|Ad|Türkçe}}=...  True
# şırlama         =={{Dil|Türkçe}}==\n==={{Söz türü|Ad|Türkçe}}=...  True
# şırlamak        =={{Dil|Türkçe}}==\n==={{Söz türü|Eylem|Türkçe...  True
# şırlanyağı      {{düzenle}}\n=={{Dil|Türkçe}}==\n==={{Söz türü...  True
# şırlağan        =={{Dil|Çağatayca}}==\n==={{Söz türü|Ad|Çağata...  True
# şırpıntı        =={{Dil|Türkçe}}==\n==={{Söz türü|Eylem|Türkçe...  True
# şırıl şırıl     =={{Dil|Türkçe}}==\n==={{Söztürü|Zarf|Türkçe}}...  True
# şırıldama       =={{Dil|Türkçe}}==\n==={{Söz türü|Ad|Türkçe}}=...  True
# şırıldamak      =={{Dil|Türkçe}}==\n==={{Söz türü|Eylem|Türkçe...  True
# şırıltı         =={{Dil|Türkçe}}==\n==={{Söz türü|Ad|Türkçe}}=...  True
# şırınga         {{düzenle}}\n=={{Dil|Türkçe}}==\n==={{Söz türü...  True
# şırınga etmek   =={{Dil|Türkçe}}==\n==={{Söz türü|Eylem|Türkçe...  True
# şırınga yapmak  =={{Dil|Türkçe}}==\n==={{Söz türü|Eylem|Türkçe...  True
# şırıngalama     =={{Dil|Türkçe}}==\n==={{Söz türü|Ad|Türkçe}}=...  True
# şırıngalamak    =={{Dil|Türkçe}}==\n==={{Söz türü|Eylem|Türkçe...  True
# şıvgın          {{düzenle}}\n=={{Dil|Türkçe}}==\n==={{Söz türü...  True
# π               =={{Dil|Türkçe}}==\n==={{Söztürü|Simge|Türkçe}...  True
# مصايف           =={{Dil|Türkçe}}==\n==={{Söz türü|İsim|Arapça}...  True
#
#                         etyms
# -a                        NaN
# -acak                     NaN
# -ak                       NaN
# -aki                      NaN
# -alım                     NaN
# -amaç                     NaN
# -anç            [Eski Türkçe]
# -ar                       NaN
# -ağan                     NaN
# -ca                  [Türkçe]
# -ce                  [Türkçe]
# -cı                       NaN
# -da                       NaN
# -dan                      NaN
# -daş                      NaN
# -de                       NaN
# -de hâli             [Türkçe]
# -den                      NaN
# -den hâli            [Türkçe]
# -deş                      NaN
# -dik                      NaN
# -dirik                    NaN
# -dı                       NaN
# -dırık                    NaN
# -e                        NaN
# -e hâli              [Türkçe]
# -elim                     NaN
# -enç            [Eski Türkçe]
# -fobi               [Latince]
# -gaç                      NaN
# ...                       ...
# şıpşıp                    NaN
# şıra                       []
# şıra ölçer                NaN
# şıracı               [Türkçe]
# şıracılık                 NaN
# şırak                [Türkçe]
# şırak şırak               NaN
# şırakkadak                NaN
# şıralı               [Türkçe]
# şıralık              [Türkçe]
# şıralık üzüm         [Türkçe]
# şıraölçer            [Türkçe]
# şırfıntı             [Türkçe]
# şırlama              [Türkçe]
# şırlamak             [Türkçe]
# şırlanyağı                NaN
# şırlağan                  NaN
# şırpıntı                  NaN
# şırıl şırıl          [Türkçe]
# şırıldama            [Türkçe]
# şırıldamak           [Türkçe]
# şırıltı              [Türkçe]
# şırınga                   NaN
# şırınga etmek        [Türkçe]
# şırınga yapmak       [Türkçe]
# şırıngalama          [Türkçe]
# şırıngalamak         [Türkçe]
# şıvgın                    NaN
# π                         NaN
# مصايف                     NaN
#
# [183739 rows x 4 columns]

# %%
etym_lookup = {}
dftr_etym = dftr[pd.notnull(dftr["etyms"])]

for r in dftr_etym.iterrows():
    e = r[1]["etyms"]
    if len(e) > 0:
        etym_lookup[r[0]] = e[0]

# %%
pickle.dump(etym_lookup, open("./trwiktionary_etym_lookup.pkl", "w"))
